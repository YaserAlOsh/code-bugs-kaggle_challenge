# %% [markdown]
# # Cleaning data

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("/kaggle/input/uos-ai-week-2023where-theres-code-theres-bug/train.csv")

# %%
import re
def remove_empty(data,column):
    idxs = data[(data[column].str.contains(r'(?m)^.*\n.*\n\s*\n.*\n.*')) & (data["label"]==1)].index
    return data.drop(idxs)
def clean_code(code):
    # Remove comments
    code = re.sub(r'(?m)^\s*#.*\n?', '', code) # python
    code = re.sub(r'(?m)^\s*//.*\n?', '', code) # //
    code = re.sub(r'(?m)^\s*(\/\*)?[\S\s]*\*\/', '', code) # comment blocks
    
    # Remove extra whitespace
    code = re.sub(r'\s+', ' ', code)
    # split
    code = ' '.join(re.split(r'([\(\)\{\}\;\:\[\]\&\=\<\>\,\.\+\-\/\*])',code))
    
    # remove numericals
    def numrepl(matchobj):
        return matchobj.group(1) + '<NUM>'
    code = re.sub(r'([^a-zA-Z0-9_]){1}\d+(?:\.\d+)?f?',numrepl,code)
    # remove strings
    code = re.sub('".*"','<STR>',code)
    # Remove leading and trailing whitespace
    code = code.strip()
    return code

# %%
data["code"].apply(lambda x: len(x.split(" "))).describe()
# Out:
# count    209786.000000
# mean         39.616347
# std          30.473218
# min           1.000000
# 25%          17.000000
# 50%          35.000000
# 75%          54.000000
# max        1467.000000
# Name: code, dtype: float64

# %%
data.file_extension.value_counts()
# Out:
# java    98763
# py      59337
# cpp     32821
# rs      12761
# js       4673
# ts        845
# kt        481
# c         105
# Name: file_extension, dtype: int64

# %%
data.label.value_counts()
# Out:
# 0    144123
# 1     65663
# Name: label, dtype: int64

# %%
data = remove_empty(data,'code')
data['clean_code'] = data['code'].apply(lambda x : clean_code(x))
data.head()
# Out:
#            id                                               code  \
# 0  8e7e71745d                  a0 = alpha_winder(0)\n        ...
# 1  f67fb60d2f        [&](const ExprHandle& m, const ExprHandl...
# 3  ac09060d54      def test_is_fast(self):\n        for token...
# 4  c746c1badf      public Exception getException() {\n       ...
# 5  08ae206799          groups=groups,\n        bias=False,\n ...
#
#   file_extension  label                                         clean_code
# 0             py      0  a0  =  alpha_winder ( <NUM> )  rebased_winder ...
# 1            cpp      0  [  &  ]  ( const ExprHandle &  m ,  const Expr...
# 3             py      1  def test_is_fast ( self )  :  for tokenizer , ...
# 4           java      0  public Exception getException (  )   {  return...
# 5             py      0  groups = groups ,  bias = False ,  dilation = ...

# %% [markdown]
# ## Segregate Data based on file extension

# %%
def segregate_extensions(data):
    df_java = data[data['file_extension'] == 'java'].copy()
    df_py = data[data['file_extension'] == 'py'].copy()
    df_cpp = data[data['file_extension'] == 'cpp'].copy()
    df_rs = data[data['file_extension'] == 'rs'].copy()
    df_js = data[data['file_extension'] == 'js'].copy()
    df_ts = data[data['file_extension'] == 'ts'].copy()
    df_kt = data[data['file_extension'] == 'kt'].copy()
    df_c = data[data['file_extension'] == 'c'].copy()    
    return (df_java, df_py, df_cpp, df_rs, df_js, df_ts, df_kt, df_c)

# %%
(df_java, df_py, df_cpp, df_rs, df_js, df_ts, df_kt, df_c) = segregate_extensions(data)

# %%
df_java.value_counts()
# Out:
# id          code                                                                                                                                                                                                                                                                                                                                                        file_extension  label  clean_code
# 0000264569      builder.requestStaticInjection(StaticInjectionTest.Static.class);\n\n    Container c = builder.createContainer();\n\n    assertEquals("test", StaticInjectionTest.Static.s);                                                                                                                                                                            java            0      builder . requestStaticInjection ( StaticInjectionTest . Static . class )  ;  Container c  =  builder . createContainer (  )  ;  assertEquals ( <STR> ,  StaticInjectionTest . Static . s )  ;                                              1
# aa665327d3     */\n  public void publishDownstreamIssue(RoutingContext routingContext) {\n    LOGGER.debug("Info: publishDownStreamIssue method started;");\n    JsonObject requestJson = routingContext.getBodyAsJson();\n    HttpServerRequest request = routingContext.request();                                                                                    java            0      public void publishDownstreamIssue ( RoutingContext routingContext )   {  LOGGER . debug ( <STR> )  ;  JsonObject requestJson  =  routingContext . getBodyAsJson (  )  ;  HttpServerRequest request  =  routingContext . request (  )  ;    1
# aa6a2022e1  import com.pmease.commons.util.StringUtils;\n\npublic class OperationOfRepositorySet implements PrivilegedOperation {\n\n\tprivate String repositoryNames;                                                                                                                                                                                                  java            0      import com . pmease . commons . util . StringUtils ;  public class OperationOfRepositorySet implements PrivilegedOperation  {  private String repositoryNames ;                                                                             1
# aa69a23dbc                      }\n\n                    mView.updateGridHeader(VideoGroup.from(mediaGroup), mHeaders.get(MediaGroup.TYPE_SUBSCRIPTIONS));\n                }, error -> Log.e(TAG, error));\n    }                                                                                                                                                      java            0      }  mView . updateGridHeader ( VideoGroup . from ( mediaGroup )  ,  mHeaders . get ( MediaGroup . TYPE_SUBSCRIPTIONS )  )  ;   }  ,  error  -  >  Log . e ( TAG ,  error )  )  ;   }                                                         1
# aa699c2328          node2.assertLeftTuple( tuple2,\n                               context2,\n                               workingMemory );\n\n        // Create the first justifieable relationship                                                                                                                                                                  java            0      node2 . assertLeftTuple (  tuple2 ,  context2 ,  workingMemory  )  ;                                                                                                                                                                        1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ..
# 555fc0674e  \n    // $ANTLR start enum_constraint\n    // D:\\workspace\\jboss\\jbossrules\\drools-compiler\\src\\main\\resources\\org\\drools\\lang\\DRL.g:984:1: enum_constraint returns [String text] : id= ID ( ( '.' identifier )=> '.' ident= identifier )+ ;\n    public String enum_constraint() throws RecognitionException {   \n        String text = null;  java            1      public String enum_constraint (  )  throws RecognitionException  {  String text  =  null ;                                                                                                                                                  1
# 555f432ced       */\n    @ServiceMethod(returns = ReturnType.SINGLE)\n    public Mono<Response<RepositoryProperties>> getPropertiesWithResponse() {\n        return withContext(context -> this.getPropertiesWithResponse(context));\n    }                                                                                                                             java            0      @ServiceMethod ( returns  =  ReturnType . SINGLE )  public Mono < Response < RepositoryProperties >  >  getPropertiesWithResponse (  )   {  return withContext ( context  -  >  this . getPropertiesWithResponse ( context )  )  ;   }      1
# 555ea5136b          assertEquals( "wee.waa", rb.getPackages()[1].getName() );\n\n        assertEquals( 0, dir.list().length );\n    }\n                                                                                                                                                                                                                                 java            0      assertEquals (  <STR> ,  rb . getPackages (  )  [ <NUM> ]  . getName (  )   )  ;  assertEquals (  <NUM> ,  dir . list (  )  . length  )  ;   }                                                                                              1
# 555ddecded  \t\t\n\t\t@Nullable\n\t\tpublic MarkPos mark;\n\t\t\n\t}                                                                                                                                                                                                                                                                                                    java            1      @Nullable public MarkPos mark ;   }                                                                                                                                                                                                         1
# ffffaffba1  \n            } catch ( ClassNotFoundException cnfe ) {\n                throw new RuntimeDroolsException( "unable to resolve Type Declaration superclass '" + fullSuper + "'" );\n            } catch ( IOException e ) {\n                                                                                                                                java            0      }  catch  (  ClassNotFoundException cnfe  )   {  throw new RuntimeDroolsException (  <STR>  )  ;   }  catch  (  IOException e  )   {                                                                                                        1
# Length: 97578, dtype: int64

# %%
df_java
# Out:
#                 id                                               code  \
# 4       c746c1badf      public Exception getException() {\n       ...
# 6       e852600d11       * @return hubVirtualNetworkConnection Res...
# 7       2d310cad6e  \r\nimport io.onedev.server.web.behavior.UserM...
# 8       2cee71c5c5  \n    /**\n     * Get the verifierType propert...
# 12      d7657ec588       * @return a common class for general reso...
# ...            ...                                                ...
# 209776  ddca4556ee          \n        initEntityResolver();\n\n   ...
# 209777  e9337332d7  \n    // $ANTLR start "andRestriction"\n    //...
# 209778  e50517a763              .setKeyOps(createKeyOptions.getKey...
# 209779  7cda935786  import com.pmease.gitplex.core.gatekeeper.AndG...
# 209785  96f2412514  import org.apache.wicket.validation.IValidatab...
#
#        file_extension  label  \
# 4                java      0
# 6                java      0
# 7                java      1
# 8                java      0
# 12               java      0
# ...               ...    ...
# 209776           java      0
# 209777           java      1
# 209778           java      1
# 209779           java      0
# 209785           java      0
#
#                                                clean_code
# 4       public Exception getException (  )   {  return...
# 6       @ServiceMethod ( returns  =  ReturnType . SING...
# 7       import io . onedev . server . web . behavior ....
# 8       /  *  *   *  Get the verifierType property :  ...
# 12      @ServiceMethod ( returns  =  ReturnType . SING...
# ...                                                   ...
# 209776                     initEntityResolver (  )  ;   }
# 209777  public final BaseDescr andRestriction (  )  th...
# 209778  . setKeyOps ( createKeyOptions . getKeyOperati...
# 209779  import com . pmease . gitplex . core . gatekee...
# 209785  import org . apache . wicket . validation . IV...
#
# [97578 rows x 5 columns]

# %%
class Extension():
    def __init__(self,df):
        self.df = df

# %%
extensions = {ext:{} for ext in  data['file_extension'].unique()}

# %%
extensions
# Out:
# {'py': {},
#  'cpp': {},
#  'java': {},
#  'rs': {},
#  'ts': {},
#  'js': {},
#  'kt': {},
#  'c': {}}

# %%
idx=0
test_size=0
from sklearn.model_selection import train_test_split
for ext in data['file_extension'].unique():
    extensions[ext] = {'data':data[data['file_extension'] == ext].copy()}
    if test_size > 0:
        X_train, X_test, y_train, y_test = \
        train_test_split(extensions[ext]['data']['clean_code'],extensions[ext]['data']['label'], test_size=0.2)
        extensions[ext]['X_train'] = X_train
        extensions[ext]['X_test'] = X_test
        extensions[ext]['y_train'] = y_train
        extensions[ext]['y_test'] = y_test
    else:
        extensions[ext]['X_train'] = extensions[ext]['data']['clean_code']
        extensions[ext]['y_train'] = extensions[ext]['data']['label']
    idx+=1

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(data['clean_code'], data['label'], test_size=0.2)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
for et in extensions:
    extensions[et]['tokenizer'] = Tokenizer()
    extensions[et]['tokenizer'].fit_on_texts(extensions[et]['X_train'])
    extensions[et]['X_train_seq'] = extensions[et]['tokenizer'].texts_to_sequences(extensions[et]['X_train'])
    if test_size > 0:
        et['X_test_seq'] = extensions[et]['tokenizer'].texts_to_sequences(extensions[et]['X_test'])

# %%
# Pad the sequences so each sequence is the same length
max_len = 50
#X_train_seq_padded = pad_sequences(X_train_seq, max_len,padding='post',truncating='post')
#X_test_seq_padded = pad_sequences(X_test_seq, max_len,padding='post',truncating='post')
for et in extensions:
    extensions[et]['X_train_seq_padded'] = pad_sequences(extensions[et]['X_train_seq'], max_len,padding='post',truncating='post')
    if test_size > 0:
        extensions[et]['X_test_seq_padded'] = pad_sequences(extensions[et]['X_test_seq'], max_len,padding='post',truncating='post')

# %%
import keras.backend as K
from keras.layers import Dense, Embedding, LSTM
from keras.models import Sequential
import tensorflow as tf
from tensorflow import keras

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

# %% [markdown]
# # RNN

# %%
from tensorflow import keras
from keras import layers
from tensorflow import keras
from keras.layers import Dropout, BatchNormalization, Bidirectional,Dense, Embedding, LSTM
from keras.models import Sequential
for et in extensions:
    inputs = keras.Input(shape=(None,), dtype="int64")
    embedded = layers.Embedding(input_dim=len(extensions[et]['tokenizer'].index_word)+1, output_dim=128)(inputs)
    x = layers.Bidirectional(layers.LSTM(32))(embedded)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)
    extensions[et]['model'] = keras.Model(inputs, outputs)
    extensions[et]['model'].compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['accuracy','AUC'])
    extensions[et]['model'].summary()
# Out:
# 2023-01-24 14:40:08.089406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.090332: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.279983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.280798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.281550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.282274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.284367: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-24 14:40:08.545292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.546062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.546848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.547594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.548296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:08.548964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:12.658237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:12.659146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:12.659905: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:12.660710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:12.661458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:12.662174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-01-24 14:40:12.666569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-24 14:40:12.667336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 128)         3016192
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                41216
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 3,057,473
# Trainable params: 3,057,473
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, None, 128)         2379264
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,420,545
# Trainable params: 2,420,545
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, None, 128)         8251264
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 8,292,545
# Trainable params: 8,292,545
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, None, 128)         565376
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 606,657
# Trainable params: 606,657
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, None, 128)         252416
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 293,697
# Trainable params: 293,697
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, None, 128)         756096
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 797,377
# Trainable params: 797,377
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, None, 128)         169216
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 210,497
# Trainable params: 210,497
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, None, 128)         50432
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 91,713
# Trainable params: 91,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import layers
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super().__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super().__init__()
        self.token_emb = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

embed_dim = 64  # Embedding size for each token
num_heads = 4  # Number of attention heads
ff_dim = 32  # Hidden layer size in feed forward network inside transformer

for et in extensions:
    inputs = layers.Input(shape=(max_len,))
    embedding_layer = TokenAndPositionEmbedding(max_len, len(extensions[et]['tokenizer'].index_word)+1, embed_dim)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, num_heads, ff_dim)
    x = transformer_block(x)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.LayerNormalization()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.1)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)

    extensions[et]['model'] = keras.Model(inputs=inputs, outputs=outputs)
    extensions[et]['model'].compile(optimizer='adam',
                          loss='binary_crossentropy',
                          metrics=['accuracy','AUC'])
    extensions[et]['model'].summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 64)            1511296
# _________________________________________________________________
# transformer_block (Transform (None, 50, 64)            70816
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 64)                128
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 1,586,465
# Trainable params: 1,586,465
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 64)            1192832
# _________________________________________________________________
# transformer_block_1 (Transfo (None, 50, 64)            70816
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 64)                128
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 1,268,001
# Trainable params: 1,268,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 64)            4128832
# _________________________________________________________________
# transformer_block_2 (Transfo (None, 50, 64)            70816
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 64)                0
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 64)                128
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 4,204,001
# Trainable params: 4,204,001
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 64)            285888
# _________________________________________________________________
# transformer_block_3 (Transfo (None, 50, 64)            70816
# _________________________________________________________________
# global_average_pooling1d_3 ( (None, 64)                0
# _________________________________________________________________
# layer_normalization_11 (Laye (None, 64)                128
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 361,057
# Trainable params: 361,057
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 64)            129408
# _________________________________________________________________
# transformer_block_4 (Transfo (None, 50, 64)            70816
# _________________________________________________________________
# global_average_pooling1d_4 ( (None, 64)                0
# _________________________________________________________________
# layer_normalization_14 (Laye (None, 64)                128
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 204,577
# Trainable params: 204,577
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 64)            381248
# _________________________________________________________________
# transformer_block_5 (Transfo (None, 50, 64)            70816
# _________________________________________________________________
# global_average_pooling1d_5 ( (None, 64)                0
# _________________________________________________________________
# layer_normalization_17 (Laye (None, 64)                128
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 456,417
# Trainable params: 456,417
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 64)            87808
# _________________________________________________________________
# transformer_block_6 (Transfo (None, 50, 64)            70816
# _________________________________________________________________
# global_average_pooling1d_6 ( (None, 64)                0
# _________________________________________________________________
# layer_normalization_20 (Laye (None, 64)                128
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 162,977
# Trainable params: 162,977
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 64)            28416
# _________________________________________________________________
# transformer_block_7 (Transfo (None, 50, 64)            70816
# _________________________________________________________________
# global_average_pooling1d_7 ( (None, 64)                0
# _________________________________________________________________
# layer_normalization_23 (Laye (None, 64)                128
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 103,585
# Trainable params: 103,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
for et in extensions:
    callbacks = [
        keras.callbacks.ModelCheckpoint("model_{}.keras".format(et),save_best_only=True)
    ]
    extensions[et]['model_path'] = "model_{}.keras".format(et)
    if test_size > 0:
        extensions[et]['history'] = extensions[et]['model'] .fit(extensions[et]['X_train_seq_padded'], extensions[et]['y_train'], 
                                            batch_size=32, epochs=10,
                                            callbacks=callbacks,
                                            validation_data=(extensions[et]['X_test_seq_padded'], extensions[et]['y_test']))
    else:
        extensions[et]['history'] = extensions[et]['model'] .fit(extensions[et]['X_train_seq_padded'], extensions[et]['y_train'], 
                                            batch_size=32, epochs=10,
                                            callbacks=callbacks)
# Out:
# 2023-01-24 14:40:18.253335: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/10
# 2023-01-24 14:40:23.450948: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 1824/1824 [==============================] - 21s 9ms/step - loss: 0.5347 - accuracy: 0.7092 - auc: 0.7778
# Epoch 2/10
# 1824/1824 [==============================] - 15s 8ms/step - loss: 0.4389 - accuracy: 0.7803 - auc: 0.8647
# Epoch 3/10
# 1824/1824 [==============================] - 16s 9ms/step - loss: 0.3886 - accuracy: 0.8108 - auc: 0.8959
# Epoch 4/10
# 1824/1824 [==============================] - 15s 8ms/step - loss: 0.3521 - accuracy: 0.8282 - auc: 0.9152
# Epoch 5/10
# 1824/1824 [==============================] - 16s 9ms/step - loss: 0.3265 - accuracy: 0.8413 - auc: 0.9271
# Epoch 6/10
# 1824/1824 [==============================] - 15s 8ms/step - loss: 0.3038 - accuracy: 0.8496 - auc: 0.9362
# Epoch 7/10
# 1824/1824 [==============================] - 16s 9ms/step - loss: 0.2863 - accuracy: 0.8555 - auc: 0.9429
# Epoch 8/10
# 1824/1824 [==============================] - 15s 8ms/step - loss: 0.2727 - accuracy: 0.8601 - auc: 0.9476
# Epoch 9/10
# 1824/1824 [==============================] - 16s 9ms/step - loss: 0.2598 - accuracy: 0.8651 - auc: 0.9518
# Epoch 10/10
# 1824/1824 [==============================] - 15s 8ms/step - loss: 0.2478 - accuracy: 0.8701 - auc: 0.9561
# Epoch 1/10
# 1023/1023 [==============================] - 11s 9ms/step - loss: 0.5634 - accuracy: 0.7304 - auc: 0.6438
# Epoch 2/10
# 1023/1023 [==============================] - 9s 8ms/step - loss: 0.4463 - accuracy: 0.7940 - auc: 0.8230
# Epoch 3/10
# 1023/1023 [==============================] - 8s 8ms/step - loss: 0.3671 - accuracy: 0.8365 - auc: 0.8865
# Epoch 4/10
# 1023/1023 [==============================] - 8s 8ms/step - loss: 0.3155 - accuracy: 0.8603 - auc: 0.9173
# Epoch 5/10
# 1023/1023 [==============================] - 9s 9ms/step - loss: 0.2778 - accuracy: 0.8753 - auc: 0.9355
# Epoch 6/10
# 1023/1023 [==============================] - 9s 9ms/step - loss: 0.2521 - accuracy: 0.8826 - auc: 0.9460
# Epoch 7/10
# 1023/1023 [==============================] - 8s 8ms/step - loss: 0.2317 - accuracy: 0.8885 - auc: 0.9537
# Epoch 8/10
# 1023/1023 [==============================] - 9s 9ms/step - loss: 0.2218 - accuracy: 0.8940 - auc: 0.9574
# Epoch 9/10
# 1023/1023 [==============================] - 9s 8ms/step - loss: 0.2102 - accuracy: 0.8956 - auc: 0.9607
# Epoch 10/10
# 1023/1023 [==============================] - 9s 8ms/step - loss: 0.2036 - accuracy: 0.9007 - auc: 0.9634
# Epoch 1/10
# 3050/3050 [==============================] - 31s 10ms/step - loss: 0.5175 - accuracy: 0.7626 - auc: 0.6999
# Epoch 2/10
# 3050/3050 [==============================] - 29s 10ms/step - loss: 0.3896 - accuracy: 0.8275 - auc: 0.8602
# Epoch 3/10
# 3050/3050 [==============================] - 29s 10ms/step - loss: 0.3066 - accuracy: 0.8679 - auc: 0.9167
# Epoch 4/10
# 3050/3050 [==============================] - 29s 10ms/step - loss: 0.2614 - accuracy: 0.8860 - auc: 0.9398
# Epoch 5/10
# 3050/3050 [==============================] - 29s 9ms/step - loss: 0.2300 - accuracy: 0.8962 - auc: 0.9527
# Epoch 6/10
# 3050/3050 [==============================] - 29s 9ms/step - loss: 0.2089 - accuracy: 0.9035 - auc: 0.9608
# Epoch 7/10
# 3050/3050 [==============================] - 29s 10ms/step - loss: 0.1931 - accuracy: 0.9086 - auc: 0.9660
# Epoch 8/10
# 3050/3050 [==============================] - 28s 9ms/step - loss: 0.1794 - accuracy: 0.9133 - auc: 0.9707
# Epoch 9/10
# 3050/3050 [==============================] - 29s 10ms/step - loss: 0.1694 - accuracy: 0.9166 - auc: 0.9739
# Epoch 10/10
# 3050/3050 [==============================] - 29s 9ms/step - loss: 0.1599 - accuracy: 0.9223 - auc: 0.9769
# Epoch 1/10
# 399/399 [==============================] - 6s 10ms/step - loss: 0.5724 - accuracy: 0.7406 - auc: 0.5531
# Epoch 2/10
# 399/399 [==============================] - 3s 8ms/step - loss: 0.5162 - accuracy: 0.7463 - auc: 0.6980
# Epoch 3/10
# 399/399 [==============================] - 3s 8ms/step - loss: 0.4644 - accuracy: 0.7713 - auc: 0.7802
# Epoch 4/10
# 399/399 [==============================] - 3s 8ms/step - loss: 0.4181 - accuracy: 0.7973 - auc: 0.8305
# Epoch 5/10
# 399/399 [==============================] - 3s 8ms/step - loss: 0.3836 - accuracy: 0.8173 - auc: 0.8605
# Epoch 6/10
# 399/399 [==============================] - 3s 8ms/step - loss: 0.3592 - accuracy: 0.8285 - auc: 0.8789
# Epoch 7/10
# 399/399 [==============================] - 3s 9ms/step - loss: 0.3372 - accuracy: 0.8366 - auc: 0.8919
# Epoch 8/10
# 399/399 [==============================] - 3s 8ms/step - loss: 0.3186 - accuracy: 0.8460 - auc: 0.9053
# Epoch 9/10
# 399/399 [==============================] - 4s 9ms/step - loss: 0.3034 - accuracy: 0.8525 - auc: 0.9117
# Epoch 10/10
# 399/399 [==============================] - 4s 9ms/step - loss: 0.2952 - accuracy: 0.8561 - auc: 0.9141
# Epoch 1/10
# 26/26 [==============================] - 2s 9ms/step - loss: 0.7423 - accuracy: 0.5803 - auc: 0.4940
# Epoch 2/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.6638 - accuracy: 0.6423 - auc: 0.5383
# Epoch 3/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.6477 - accuracy: 0.6521 - auc: 0.5747
# Epoch 4/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.6038 - accuracy: 0.6813 - auc: 0.6613
# Epoch 5/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.4993 - accuracy: 0.7543 - auc: 0.8075
# Epoch 6/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.4296 - accuracy: 0.7981 - auc: 0.8685
# Epoch 7/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.2990 - accuracy: 0.8844 - auc: 0.9386
# Epoch 8/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.2688 - accuracy: 0.8893 - auc: 0.9513
# Epoch 9/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1906 - accuracy: 0.9270 - auc: 0.9760
# Epoch 10/10
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1537 - accuracy: 0.9343 - auc: 0.9835
# Epoch 1/10
# 144/144 [==============================] - 3s 8ms/step - loss: 0.7285 - accuracy: 0.5222 - auc: 0.5328
# Epoch 2/10
# 144/144 [==============================] - 1s 8ms/step - loss: 0.6181 - accuracy: 0.6595 - auc: 0.7140
# Epoch 3/10
# 144/144 [==============================] - 1s 8ms/step - loss: 0.4706 - accuracy: 0.7776 - auc: 0.8562
# Epoch 4/10
# 144/144 [==============================] - 1s 10ms/step - loss: 0.3482 - accuracy: 0.8512 - auc: 0.9249
# Epoch 5/10
# 144/144 [==============================] - 1s 8ms/step - loss: 0.2588 - accuracy: 0.8930 - auc: 0.9588
# Epoch 6/10
# 144/144 [==============================] - 1s 8ms/step - loss: 0.2096 - accuracy: 0.9069 - auc: 0.9726
# Epoch 7/10
# 144/144 [==============================] - 1s 8ms/step - loss: 0.1696 - accuracy: 0.9265 - auc: 0.9823
# Epoch 8/10
# 144/144 [==============================] - 1s 8ms/step - loss: 0.1448 - accuracy: 0.9349 - auc: 0.9865
# Epoch 9/10
# 144/144 [==============================] - 1s 8ms/step - loss: 0.1283 - accuracy: 0.9408 - auc: 0.9894
# Epoch 10/10
# 144/144 [==============================] - 1s 8ms/step - loss: 0.1161 - accuracy: 0.9469 - auc: 0.9913
# Epoch 1/10
# 15/15 [==============================] - 1s 6ms/step - loss: 0.5785 - accuracy: 0.7771 - auc: 0.5001
# Epoch 2/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5015 - accuracy: 0.7812 - auc: 0.5577
# Epoch 3/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5151 - accuracy: 0.8188 - auc: 0.5005
# Epoch 4/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4997 - accuracy: 0.8083 - auc: 0.5302
# Epoch 5/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4867 - accuracy: 0.8167 - auc: 0.5481
# Epoch 6/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4779 - accuracy: 0.8042 - auc: 0.5937
# Epoch 7/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4574 - accuracy: 0.8188 - auc: 0.6303
# Epoch 8/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3916 - accuracy: 0.8250 - auc: 0.7997
# Epoch 9/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2851 - accuracy: 0.8792 - auc: 0.9176
# Epoch 10/10
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1961 - accuracy: 0.9354 - auc: 0.9535
# Epoch 1/10
# 4/4 [==============================] - 2s 9ms/step - loss: 0.6572 - accuracy: 0.6667 - auc: 0.4343
# Epoch 2/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2521 - accuracy: 0.9429 - auc: 0.5194
# Epoch 3/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2420 - accuracy: 0.9429 - auc: 0.5135
# Epoch 4/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2029 - accuracy: 0.9429 - auc: 0.7466
# Epoch 5/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2005 - accuracy: 0.9429 - auc: 0.7079
# Epoch 6/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1974 - accuracy: 0.9429 - auc: 0.7660
# Epoch 7/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2256 - accuracy: 0.9429 - auc: 0.6069
# Epoch 8/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2276 - accuracy: 0.9429 - auc: 0.5884
# Epoch 9/10
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2031 - accuracy: 0.9429 - auc: 0.7256
# Epoch 10/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2181 - accuracy: 0.9429 - auc: 0.6818

# %% [markdown]
# #####

# %% [markdown]
# labels, axis=1 is## Submission

# %%
# load test.csv,
submission = pd.read_csv(r'/kaggle/input/uos-ai-week-2023where-theres-code-theres-bug/test.csv')
submission
# Out:
#                id                                               code  \
# 0      9125d50679          self.play(\n            pixels_to_dete...
# 1      dc3b7fbe81                  *[\n                    Changi...
# 2      3276506966                                                ...
# 3      556239b7c2      """\n    A = torch.randn(*(batch_dims + (m...
# 4      15c4f39064      abstract fun getAllOutdated(outdatedThresh...
# ...           ...                                                ...
# 22994  13696067b8                help="The root of the backing fi...
# 22995  59c99cf33d  \n    public void doLeftDeletes(LeftTupleSink ...
# 22996  4755e18b90                  gpu_last_map_locations,\n     ...
# 22997  6de73b77c1                          break;\r\n            ...
# 22998  fb303af42c  \t\tbind(MailManager.class).to(DefaultMailMana...
#
#       file_extension
# 0                 py
# 1                 py
# 2                cpp
# 3                 py
# 4                 kt
# ...              ...
# 22994             py
# 22995           java
# 22996             py
# 22997           java
# 22998           java
#
# [22999 rows x 3 columns]

# %%
import tensorflow as tf

# create a function, that given a string comment, it predicts topic as a string,
def predict_bug(code):
    'input: "x=y\nz=w\n for b in range(5,4):\nz+=b\nprint(z)"'
    'returns: 1 (buggy)'
    code = clean_code(code)
    tokens = tokenizer.texts_to_sequences(code)
    if tokens == None or tokens == [] or len(tokens) == 0:
        return 0
    #print(code)
    seq = pad_sequences(tokens,maxlen=max_len,padding='post',truncating='post')
    #print(seq)
    return model.predict(seq)

from keras.models import load_model
#model = load_model(r"/kaggle/working/bi_rnn.keras")

# store all predicted topics in one new column
submission['clean_code'] = submission['code'].apply(lambda code: clean_code(code))
submission['label'] = 0
submission_df = pd.DataFrame(columns=['id','label','code','file_extension'])
for et in submission['file_extension'].unique():
    ext = extensions[et]
    submissions_et = submission[submission['file_extension'] == et].copy()
    sequences = extensions[et]['tokenizer'].texts_to_sequences(submissions_et['clean_code'])
    sequences = pad_sequences(sequences,maxlen=max_len,padding='post',truncating='post')
    model = extensions[et]['model'] #load_model(extensions[et]['model_path'])
    submissions_et['label'] = tf.cast(tf.round(model.predict(sequences)),dtype=tf.int64)
    # now assign correct labels to submission based on ids
    submission_df = pd.concat([submission_df,submissions_et],ignore_index=True)

# drop the Comments column
submission_df = submission_df.drop(columns=['code','clean_code','file_extension'])

# save the dataframe as a .csv file for submission
submission_df.to_csv('submission.csv',index=False)

# %%
submission_df
# Out:
#                id label
# 0      9125d50679     0
# 1      dc3b7fbe81     0
# 2      556239b7c2     1
# 3      d968be6e2b     0
# 4      8001cd915d     1
# ...           ...   ...
# 22994  727bc99b9b     0
# 22995  a477322861     0
# 22996  53c603d3c0     0
# 22997  57f13c9cae     0
# 22998  3145f829dc     0
#
# [22999 rows x 2 columns]
